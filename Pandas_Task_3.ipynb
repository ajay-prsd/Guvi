# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay-prsd/Guvi/blob/main/Pandas_Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 1. Import pandas under the name pd.
import pandas as pd

# %%
#@title 2. Print the version of pandas that has been imported.
print(pd.__version__)
# Out:
# 1.3.5

# %%
#@title 3. Print out all the version information of the libraries that are required by the pandas library.
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 66e3805b8cabe977f40c05259cc3fcf7ead5687d
# python           : 3.7.15.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.133+
# Version          : #1 SMP Fri Aug 26 08:44:51 UTC 2022
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.3.5
# numpy            : 1.21.6
# pytz             : 2022.6
# dateutil         : 2.8.2
# pip              : 21.1.3
# setuptools       : 57.4.0
# Cython           : 0.29.32
# pytest           : 3.6.4
# hypothesis       : None
# sphinx           : 1.8.6
# blosc            : None
# feather          : 0.4.1
# xlsxwriter       : None
# lxml.etree       : 4.9.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : 2.9.5 (dt dec pq3 ext lo64)
# jinja2           : 2.11.3
# IPython          : 7.9.0
# ...

# %%
#@title 4. Create a DataFrame df from this dictionary data which has the index labels.
import numpy as np
import pandas as pd
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data, index = labels)

# %%
#@title 5. Display a summary of the basic information about this DataFrame and its data.
df = pd.DataFrame(data, index = labels)
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#@title 6. Return the first 3 rows of the DataFrame df
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
#@title 7. Select just the 'animal' and 'age' columns from the DataFrame df.
df.loc[:, ["animal", "age"]]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
#@title 8. Select the data in rows [3, 4, 8] and in columns ['animal', 'age'].
df.iloc[[3, 4, 8], [0, 1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
#@title 9. Select only the rows where the number of visits is greater than 3.
df.loc[df.visits > 3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
#@title 10. Select the rows where the age is missing, i.e. is NaN.
df.loc[df.age.isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
#@title 11. Select the rows where the animal is a cat and the age is less than 3.
df.loc[(df.animal == "cat") & (df.age < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
#@title 12. Select the rows the age is between 2 and 4 (inclusive).
df.loc[(df.age >= 2) & (df.age <= 4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
#@title 13#. Change the age in row 'f' to 1.5.
df['age'].mask(df['age'] == 2 , 1.5, inplace=True)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#@title 14. Calculate the sum of all visits (the total number of visits).
sumOfAllVisits = sum(df.visits)
print(sumOfAllVisits)
# Out:
# 19

# %%
#@title 15. Calculate the mean age for each different animal in df.
meanAge = df.groupby("animal")["age"].mean()
print(meanAge)
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %%
#@title 16. Append a new row 'k' to df with your choice of values for each column. Then delete that row to return the original DataFrame.
k = {'animal': 'dog', 'age': 3.5, 'visits': 4, 'priority':'yes'}
df = df.append(k, ignore_index = True)
print(df)
df.drop(index=df.index[-1:], inplace = True)
print(df)
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 1    cat  3.0       3      yes
# 2  snake  0.5       2       no
# 3    dog  NaN       3      yes
# 4    dog  5.0       2       no
# 5    cat  2.0       3       no
# 6  snake  4.5       1       no
# 7    cat  NaN       1      yes
# 8    dog  7.0       2       no
# 9    dog  3.0       1       no

# %%
#@title 17. Count the number of each type of animal in df.

animalCount = df["animal"].value_counts()
print(animalCount)
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
#@title 18. Sort df first by the values in the 'age' in decending order, then by the value in the 'visit' column in ascending order.
print(df.sort_values(by = "age", ascending = False))
print(df.sort_values(by = "visits"))
# Out:
#   animal  age  visits priority
# 8    dog  7.0       2       no
# 4    dog  5.0       2       no
# 6  snake  4.5       1       no
# 1    cat  3.0       3      yes
# 9    dog  3.0       1       no
# 0    cat  2.5       1      yes
# 5    cat  2.0       3       no
# 2  snake  0.5       2       no
# 3    dog  NaN       3      yes
# 7    cat  NaN       1      yes
#   animal  age  visits priority
# 0    cat  2.5       1      yes
# 6  snake  4.5       1       no
# 7    cat  NaN       1      yes
# 9    dog  3.0       1       no
# 2  snake  0.5       2       no
# 4    dog  5.0       2       no
# 8    dog  7.0       2       no
# 1    cat  3.0       3      yes
# 3    dog  NaN       3      yes
# 5    cat  2.0       3       no

# %%
#@title 19. The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be True and 'no' should be False.
condition = [(df["priority"] == "yes"),
             (df["priority"] == "no")]
value = ["True", "False"]
df["priority"] = np.select(condition, value)
df
# Out:
#   animal  age  visits priority
# 0    cat  2.5       1     True
# 1    cat  3.0       3     True
# 2  snake  0.5       2    False
# 3    dog  NaN       3     True
# 4    dog  5.0       2    False
# 5    cat  2.0       3    False
# 6  snake  4.5       1    False
# 7    cat  NaN       1     True
# 8    dog  7.0       2    False
# 9    dog  3.0       1    False

# %%
#@title 20#. In the 'animal' column, change the 'snake' entries to 'python'.
condition = [(df["animal"] == "snake")]
df["animal"] = np.select(condition, ["python"])
df
# Out:
#    animal  age  visits priority
# a       0  2.5       1      yes
# b       0  3.0       3      yes
# c  python  0.5       2       no
# d       0  NaN       3      yes
# e       0  5.0       2       no
# f       0  2.0       3       no
# g  python  4.5       1       no
# h       0  NaN       1      yes
# i       0  7.0       2       no
# j       0  3.0       1       no

# %%
#@title 21. For each animal type and each number of visits, find the mean age. In other words, each row is an animal, each column is a number of visits and the values are the mean ages (hint: use a pivot table).
noOfVisits = df.groupby(["animal", "visits"])["age"].mean()
print(noOfVisits)
# Out:
# animal  visits
# cat     1         2.5
#         3         2.5
# dog     1         3.0
#         2         6.0
#         3         NaN
# snake   1         4.5
#         2         0.5
# Name: age, dtype: float64

# %%
#@title 22#. How do you filter out rows which contain the same integer as the row immediately above? { display-mode: "form" }
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
#@title 23. How do you subtract the row mean from each element in the row?
import numpy as np
df = pd.DataFrame(np.random.random(size=(5, 3))) # a 5x3 frame of float values
print(df.sub(df.mean(axis=1), axis=0))
# Out:
#           0         1         2
# 0 -0.076715  0.173289 -0.096574
# 1  0.211982 -0.160149 -0.051833
# 2 -0.116868  0.098284  0.018584
# 3  0.129185 -0.435582  0.306396
# 4 -0.457670  0.307606  0.150064

# %%
#@title 24. Which column of numbers has the smallest sum? (Find that column's label.)
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
print(df.sum().idxmin())
# Out:
# i

# %%
#@title 25. How do you count how many unique rows a DataFrame has (i.e. ignore all rows that are duplicates)?
print(len(df["A"].drop_duplicates()))
# Out:
# 7

# %%
#@title 26. You have a DataFrame that consists of 10 columns of floating--point numbers. Suppose that exactly 5 entries in each row are NaN values. For each row of the DataFrame, find the column which contains the third NaN value.

# %%
#@title 27. For each group, find the sum of the three greatest values.
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'), 
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
print(df.groupby('grps').apply(lambda x: x.vals.nlargest(3).sum()))
# Out:
# grps
# a    409
# b    156
# c    345
# dtype: int64

# %%
#@title 28#. A DataFrame has two integer columns 'A' and 'B'. The values in 'A' are between 1 and 100 (inclusive). For each group of 10 consecutive integers in 'A' (i.e. (0, 10], (10, 20], ...), calculate the sum of the corresponding values in column 'B'.

# %%
#@title 29. For each value, count the difference back to the previous zero (or the start of the Series, whichever is closer). These values should therefore be [1, 2, 0, 1, 2, 3, 4, 0, 1, 2]. Make this a new column 'Y'.
import pandas as pd
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
df
# Out:
#    X
# 0  7
# 1  2
# 2  0
# 3  3
# 4  4
# 5  2
# 6  5
# 7  0
# 8  3
# 9  4

# %%
#@title 30. Consider a DataFrame containing rows and columns of purely numerical data. Create a list of the row-column index locations of the 3 largest values.
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
print(df)
df.unstack().sort_values()[-3:].index.tolist()
# Out:
#    X
# 0  7
# 1  2
# 2  0
# 3  3
# 4  4
# 5  2
# 6  5
# 7  0
# 8  3
# 9  4
# [('X', 9), ('X', 6), ('X', 0)]

# %%
#@title 31. Given a DataFrame with a column of group IDs, 'grps', and a column of corresponding integer values, 'vals', replace any negative values in 'vals' with the group mean.
import numpy as np
df = pd.DataFrame({"vals": np.random.RandomState(31).randint(-30, 30, size=15), 
                   "grps": np.random.RandomState(31).choice(["A", "B"], 15)})
df
#s = df.vals < 0 
#df.where(s, 0)

# %%
#@title 32. Implement a rolling mean over groups with window size 3, which ignores NaN value. For example consider the following DataFrame:
df = pd.DataFrame({'group': list('aabbabbbabab'),
                       'value': [1, 2, 3, np.nan, 2, 3, 
                                 np.nan, 1, 7, 3, np.nan, 8]})
#print(df)
group = df.groupby(['group'])['value']
group_na = df.fillna(0).groupby(['group'])['value']
rollMean = group_na.rolling(3, min_periods=1).sum() / group.rolling(3, min_periods=1).count()
rollMean.reset_index(level=0, drop=True).sort_index()

# %%
#@title 33. Create a DatetimeIndex that contains each business day of 2015 and use it to index a Series of random numbers. Let's call this Series s.
dateTimeIndex = pd.date_range(start = '2015-01-01', end = '2015-12-31')
dateTimeIndex
s = pd.Series(np.random.rand(len(dateTimeIndex)), index = dateTimeIndex)
s
# Out:
# 2015-01-01    0.741225
# 2015-01-02    0.853499
# 2015-01-03    0.219580
# 2015-01-04    0.899259
# 2015-01-05    0.992689
#                 ...
# 2015-12-27    0.719319
# 2015-12-28    0.656279
# 2015-12-29    0.308723
# 2015-12-30    0.518537
# 2015-12-31    0.663616
# Freq: D, Length: 365, dtype: float64

# %%
#@title 34. Find the sum of the values in s for every Wednesday.
s = pd.Series(np.random.rand(len(dateTimeIndex)), index = dateTimeIndex)
s[s.index.weekday == 2].sum()
# Out:
# 26.239604097045927

# %%
#@title 35. For each calendar month in s, find the mean of values.
s.resample('M').mean()

# %%
#@title 36. For each group of four consecutive calendar months in s, find the date on which the highest value occurred.

# %%
#@title 37. Create a DateTimeIndex consisting of the third Thursday in each month for the years 2015 and 2016.
dateTimeIndex = pd.date_range('2015-01-01', '2016-12-31', freq='WOM-3THU')
dateTimeIndex
# Out:
# DatetimeIndex(['2015-01-15', '2015-02-19', '2015-03-19', '2015-04-16',
#                '2015-05-21', '2015-06-18', '2015-07-16', '2015-08-20',
#                '2015-09-17', '2015-10-15', '2015-11-19', '2015-12-17',
#                '2016-01-21', '2016-02-18', '2016-03-17', '2016-04-21',
#                '2016-05-19', '2016-06-16', '2016-07-21', '2016-08-18',
#                '2016-09-15', '2016-10-20', '2016-11-17', '2016-12-15'],
#               dtype='datetime64[ns]', freq='WOM-3THU')

# %%
#@title 38. Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float column).
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
#@title 39. The From_To column would be better as two separate columns! Split each string on the underscore delimiter _ to give a new temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame.
tempCol = df.From_To.str.split("_", expand = True)
tempCol
# Out:
#           0          1
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
#@title 40. Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)
tempCol[0] = tempCol[0].str.capitalize()
tempCol[1] = tempCol[1].str.capitalize()
tempCol
# Out:
#           0          1
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
#@title 41. Delete the From_To column from df and attach the temporary DataFrame from the previous questions.
df = df.drop('From_To', axis = 1)
df = df.join(tempCol)
df
# Out:
#    FlightNumber  RecentDelays              Airline         0          1
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
#@title 42. In the Airline column, you can see some extra puctuation and symbols have appeared around the airline names. Pull out just the airline name. E.g. '(British Airways. )' should become 'British Airways'.
df['Airline'] = df['Airline'].str.extract('([a-zA-Z\s]+)', expand=False).str.strip()
df
# Out:
#    FlightNumber  RecentDelays          Airline         0          1
# 0         10045      [23, 47]              KLM    London      Paris
# 1         10055            []       Air France    Madrid      Milan
# 2         10065  [24, 43, 87]  British Airways    London  Stockholm
# 3         10075          [13]       Air France  Budapest      Paris
# 4         10085      [67, 32]        Swiss Air  Brussels     London

# %%
#@title 43. In the RecentDelays column, the values have been entered into the DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN.Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df with delays.

# %%
#@title 44.  Given the lists letters = ['A', 'B', 'C'] and numbers = list(range(10)), construct a MultiIndex object from the product of the two lists. Use it to index a Series of random numbers. Call this Series s.
letters = ['A', 'B', 'C']
numbers = list(range(10))
mIndex = pd.MultiIndex.from_product([letters, numbers])
s = pd.Series(np.random.rand(30), index=mIndex)
s
# Out:
# A  0    0.812412
#    1    0.225274
#    2    0.922665
#    3    0.095612
#    4    0.609167
#    5    0.397703
#    6    0.476603
#    7    0.824725
#    8    0.380761
#    9    0.173347
# B  0    0.733249
#    1    0.961357
#    2    0.249836
#    3    0.447140
#    4    0.688566
#    5    0.782963
#    6    0.166559
#    7    0.791007
#    8    0.444635
#    9    0.583972
# C  0    0.300453
#    1    0.964176
#    2    0.085504
#    3    0.208015
#    4    0.253006
#    5    0.010113
#    6    0.324626
#    7    0.251272
#    8    0.099675
#    9    0.787702
# dtype: float64

# %%
#@title 45. Check the index of s is lexicographically sorted (this is a necessary property for indexing to work correctly with a MultiIndex).
s.index.is_lexsorted()
s

# %%
#@title 46. Select the labels 1, 3 and 6 from the second level of the MultiIndexed Series.
s.loc[:,[1, 3, 6]]
s
# Out:
# A  0    0.361914
#    1    0.799238
#    2    0.861659
#    3    0.521829
#    4    0.681545
#    5    0.225536
#    6    0.504538
#    7    0.083035
#    8    0.549379
#    9    0.810329
# B  0    0.285806
#    1    0.030417
#    2    0.552820
#    3    0.705804
#    4    0.795893
#    5    0.037340
#    6    0.639475
#    7    0.318894
#    8    0.172794
#    9    0.812030
# C  0    0.232352
#    1    0.602328
#    2    0.021135
#    3    0.457901
#    4    0.092937
#    5    0.320790
#    6    0.078573
#    7    0.034769
#    8    0.955144
#    9    0.833915
# dtype: float64

# %%
#@title 47. Slice the Series s; slice up to label 'B' for the first level and from label 5 onwards for the second level.
s.loc[pd.IndexSlice[:'B', 5:]]
s

# %%
#@title 48. Sum the values in s for each label in the first level (you should have Series giving you a total for labels A, B and C).
s.sum(level=0)
s

# %%
#@title 49. Suppose that sum() (and other methods) did not accept a level keyword argument. How else could you perform the equivalent of s.sum(level=1)?
s.unstack().sum(axis=0)
s

# %%
#@title 50. Exchange the levels of the MultiIndex so we have an index of the form (letters, numbers). Is this new Series properly lexsorted? If not, sort it.
val = s.swaplevel(0, 1)
if not val.index.is_lexsorted():
    val = val.sort_index()
val
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0  A    0.812412
#    B    0.733249
#    C    0.300453
# 1  A    0.225274
#    B    0.961357
#    C    0.964176
# 2  A    0.922665
#    B    0.249836
#    C    0.085504
# 3  A    0.095612
#    B    0.447140
#    C    0.208015
# 4  A    0.609167
#    B    0.688566
#    C    0.253006
# 5  A    0.397703
#    B    0.782963
#    C    0.010113
# 6  A    0.476603
#    B    0.166559
#    C    0.324626
# 7  A    0.824725
#    B    0.791007
#    C    0.251272
# 8  A    0.380761
#    B    0.444635
#    C    0.099675
# 9  A    0.173347
#    B    0.583972
#    C    0.787702
# dtype: float64

# %%
#@title 56. For starters, make a scatter plot of this random data, but use black X's instead of the default markers.
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
df = pd.DataFrame({"xs":[1,5,2,8,1], "ys":[4,2,1,9,6]})
df.plot.scatter("xs", "ys", color = "black", marker = "x")
df

# %%
#@title 57. Columns in your DataFrame can also be used to modify colors and sizes. Bill has been keeping track of his performance at work over time, as well as how good he was feeling that day, and whether he had a cup of coffee in the morning. Make a plot which incorporates all four features of this DataFrame.
df = pd.DataFrame({"productivity":[5,2,3,1,4,5,6,7,8,3,4,8,9],
                   "hours_in"    :[1,9,6,5,3,9,2,9,1,7,4,2,2],
                   "happiness"   :[2,1,3,2,3,1,2,3,1,2,2,1,3],
                   "caffienated" :[0,0,1,1,0,0,0,0,1,1,0,1,0]})
df.plot.scatter("hours_in", "productivity", "happiness", "caffienated")

# %%
#@title 58.
import pandas as pd 
import numpy as np
df = pd.DataFrame({"revenue":[57,68,63,71,72,90,80,62,59,51,47,52],
                   "advertising":[2.1,1.9,2.7,3.0,3.6,3.2,2.7,2.4,1.8,1.6,1.3,1.9],
                   "month":range(12)
                  })
df
ax = df.plot.bar("month", "revenue", color = "yellow")
df.plot.line("month", "advertising", color = "black", secondary_y = True, ax = ax)
ax.set_xlim((-1,12))
# Out:
# (-1.0, 12.0)

# %%
#@title 59. Generate a day's worth of random stock data, and aggregate / reformat it so that it has hourly summaries of the opening, highest, lowest, and closing prices
import numpy as np
import pandas as pd
def float_to_time(x):
    return str(int(x)) + ":" + str(int(x%1 * 60)).zfill(2) + ":" + str(int(x*60 % 1 * 60)).zfill(2)

def day_stock_data():
    #NYSE is open from 9:30 to 4:00
    time = 9.5
    price = 100
    results = [(float_to_time(time), price)]
    while time < 16:
        elapsed = np.random.exponential(.001)
        time += elapsed
        if time > 16:
            break
        price_diff = np.random.uniform(.999, 1.001)
        price *= price_diff
        results.append((float_to_time(time), price))
    
    
    df = pd.DataFrame(results, columns = ['time','price'])
    df.time = pd.to_datetime(df.time)
    return df

#Don't read me unless you get stuck!
def plot_candlestick(agg):
    """
    agg is a DataFrame which has a DatetimeIndex and five columns: ["open","high","low","close","color"]
    """
    fig, ax = plt.subplots()
    for time in agg.index:
        ax.plot([time.hour] * 2, agg.loc[time, ["high","low"]].values, color = "black")
        ax.plot([time.hour] * 2, agg.loc[time, ["open","close"]].values, color = agg.loc[time, "color"], linewidth = 10)

    ax.set_xlim((8,16))
    ax.set_ylabel("Price")
    ax.set_xlabel("Hour")
    ax.set_title("OHLC of Stock Value During Trading Day")
    plt.show()

df = day_stock_data()
df.head()

df.set_index("time", inplace = True)
val = df.resample("H").ohlc()
val.columns = val.columns.droplevel()
val["color"] = (val.close > val.open).map({True:"blue",False:"yellow"})
val.head()
# Out:
#                            open        high        low       close   color
# time
# 2022-11-30 09:00:00  100.000000  101.202491  99.482326  101.068981    blue
# 2022-11-30 10:00:00  101.030388  102.075120  99.939741  100.034292  yellow
# 2022-11-30 11:00:00  100.043405  100.208403  98.077517  100.019554  yellow
# 2022-11-30 12:00:00  100.076333  100.819953  97.143821   99.030724  yellow
# 2022-11-30 13:00:00   99.101526  102.062186  98.892732  100.711310    blue

# %%
#@title 60. Now that you have your properly-formatted data, try to plot it yourself as a candlestick chart. Use the plot_candlestick(df) function above, or matplotlib's plot documentation if you get stuck.
import matplotlib.pyplot as plt
plot_candlestick(val)
